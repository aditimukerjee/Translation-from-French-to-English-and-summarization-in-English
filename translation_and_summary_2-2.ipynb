# %% [markdown]
# # ***Installing the Packages***

# %%
 # !pip install --no-cache-dir transformers sentencepiece
# Out:
# ...
#      |████████████████████████████████| 3.4 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 60.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 67.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 67.3 MB/s
# ...
#      |████████████████████████████████| 61 kB 19.9 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 59.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install dl-translate

# %% [markdown]
# # ***Importing the dependencies***

# %%
import time
import dl_translate as dlt

# %% [markdown]
# # ***TRANSLATION TASK***

# %% [markdown]
# Article link: https://www.lefigaro.fr/sciences/omicron-l-efficacite-d-une-troisieme-dose-pfizer-declinerait-a-45-des-dix-semaines-selon-l-agence-sanitaire-britannique-20211227

# %%
article = '''Une étude de l'UK Health Security Agency rapporte que l'efficacité de la dose de rappel du laboratoire déclinerait pour les formes symptomatiques.

Le variant Omicron, qui se propage à une vitesse galopante, met à mal l'efficacité des vaccins. C'est en tout cas le constat qui se dégage de plusieurs études réalisées notamment en Afrique du Sud et au Royaume-Uni. En fin de semaine dernière, l'agence sanitaire britannique (UK Health Security Agency) a ainsi indiqué dans une analyse - qui se veut prudente - que l'efficacité de la troisième dose (ou booster) décline près de dix semaines après l'injection.

Dans le détail, l'étude britannique suggère qu'un schéma vaccinal à trois doses réalisé uniquement avec des doses Pfizer-BioNTech confère une protection de 70% contre les formes symptomatiques du coronavirus liées au variant Omicron. Mais cette immunité décline rapidement par la suite. Ainsi, cette protection n'est plus que de 45% au bout de dix semaines, selon les données de l'étude.

La donne est différente pour les patients qui ont reçu des doses provenant d'autres laboratoires, ou un «mélange». Pour les patients qui ont d'abord eu un vaccin AstraZeneca, puis un rappel Moderna ou Pfizer-BioNTech, la protection au bout de dix semaines serait respectivement de 45% et de 35%.

Évolution de l'efficacité vaccinale avec un schéma composé de deux doses de vaccin AstraZeneca, et alternativement d'un rappel Pfzer-BioNTech ou Moderna. UK Health Security Agency

Évolution de l'efficacité vaccinale avec un schéma composé de deux doses de vaccin Moderna UK Health Security Agency
Dernier cas de figure: les patients qui ont d'abord reçu deux doses de vaccin Pfizer-BioNTech avant d'obtenir un rappel avec une dose du laboratoire Moderna. En France, ce schéma concerne seulement les personnes âgées de plus de trente ans. Ils semblent être les plus durablement protégés, puisque l'efficacité du vaccin se maintiendrait entre 70 et 75% au bout de dix semaines.

Évolution de l'efficacité vaccinale avec un schéma composé de deux doses de vaccin Pfizer-BioNtech, et alternativement d'un rappel Pfzer-BioNTech ou Moderna. UK Health Security Agency
Protection contre les formes graves

Les résultats de cette étude sont à examiner avec précaution, comme le souligne l'agence sanitaire britannique, qui met en garde contre de possibles biais liés au profil des personnes infectées par Omicron. En outre, l'échantillon examiné dans le cadre de cette étude est relativement limité, puisqu'il est composé de 147.587 cas de variant Delta et de 68.489 cas de variant Omicron.

Ces résultats s'ajoutent malgré tout à un ensemble d'études publié ces dernières semaines et qui posent la question de l'efficacité du vaccin face à ce variant. Ainsi, selon une analyse de données de vie réelle publiée le mardi 14 décembre par un groupe d'assurance de santé sud-africaine, la protection contre les contaminations liées au nouveau variant chuterait au fil du temps pour atteindre 30% dans le cadre d'un schéma réalisé avec deux doses (seulement) de vaccin Pfizer-BioNTech.

En revanche, cette étude constate une efficacité contre les formes graves (70%). Elle est en cela confortée par l'analyse publiée par l'agence de sécurité sanitaire britannique, qui estime que les personnes contaminées par Omicron ont entre 50 et 70% moins de chances d'être hospitalisés.

Mais là encore, il faut examiner les résultats avec prudence, puisque comme le souligne l'agence, l'analyse reste «hautement incertaine à cause du faible nombre des malades atteints par Omicron actuellement à l'hôpital, l'impossibilité de mesurer effectivement toutes les infections précédentes et la propagation limitée d'Omicron parmi les groupes les plus âgés».

'''

# %%
article
# Out:
# "Une étude de l'UK Health Security Agency rapporte que l'efficacité de la dose de rappel du laboratoire déclinerait pour les formes symptomatiques.\n\nLe variant Omicron, qui se propage à une vitesse galopante, met à mal l'efficacité des vaccins. C'est en tout cas le constat qui se dégage de plusieurs études réalisées notamment en Afrique du Sud et au Royaume-Uni. En fin de semaine dernière, l'agence sanitaire britannique (UK Health Security Agency) a ainsi indiqué dans une analyse - qui se veut prudente - que l'efficacité de la troisième dose (ou booster) décline près de dix semaines après l'injection.\n\nDans le détail, l'étude britannique suggère qu'un schéma vaccinal à trois doses réalisé uniquement avec des doses Pfizer-BioNTech confère une protection de 70% contre les formes symptomatiques du coronavirus liées au variant Omicron. Mais cette immunité décline rapidement par la suite. Ainsi, cette protection n'est plus que de 45% au bout de dix semaines, selon les données de l'étu
# ...

# %% [markdown]
# # ***TRANSLATION MODEL -1***

# %%
#https://pythonrepo.com/repo/xhlulu-dl-translate

start_time=time.time()

from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

# translate French to English
tokenizer.src_lang = "fr_XX"
encoded_1 = tokenizer(article[0:2000], return_tensors="pt")
generated_tokens_1 = model.generate(**encoded_1, forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"])
decode_trans_1 = tokenizer.batch_decode(generated_tokens_1, skip_special_tokens=True)

print(decode_trans_1)

end_time=time.time()
t_1 = end_time-start_time
print(t_1)
# Out:
# Downloading:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/649 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/529 [00:00<?, ?B/s]
# ...

# %%
start_time=time.time()

from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

# translate French to English
tokenizer.src_lang = "fr_XX"
encoded_2 = tokenizer(article[2001:4000], return_tensors="pt")
generated_tokens_2 = model.generate(**encoded_2, forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"])
decode_trans_2 = tokenizer.batch_decode(generated_tokens_2, skip_special_tokens=True)

print(decode_trans_2)

end_time=time.time()
t_2 = end_time-start_time
print(t_2)
# Out:
# ['The results of this study are to be examined with caution, as the UK Health Security Agency points out, which warns against possible biases related to the profile of people infected with Omicron. In addition, the sample examined in this study is relatively limited, as it consists of 147,587 cases of the Delta variant and 68,489 cases of the Omicron variant. These results are nevertheless in addition to a series of studies published in recent weeks which raise the question of the effectiveness of the vaccine against this variant. Thus, according to a real life data analysis published on Tuesday 14 December by a South African health insurance group, protection against contaminations linked to the new variant would decline over time to reach 30% under a scheme conducted with two doses (only) of the Pfizer-BioNTech vaccine. On the other hand, this study shows effectiveness against serious forms (70%']
# 74.1436460018158

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

# translate French to English
tokenizer.src_lang = "fr_XX"
encoded_3 = tokenizer(article[4001:6000], return_tensors="pt")
generated_tokens_3 = model.generate(**encoded_3, forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"])
decode_trans_3 = tokenizer.batch_decode(generated_tokens_3, skip_special_tokens=True)

print(decode_trans_3)

end_time=time.time()
time = end_time-start_time
print(time)
# Out:
# ["This is the first time I've heard of it."]
# 91.59744644165039

# %%
total_time = t_1 + t_2
print(total_time)
# Out:
# 213.2834599018097

# %%
decoded_tranlated = decode_trans_1 + decode_trans_2
print(decoded_tranlated)
# Out:
# ['A UK Health Security Agency study reports that the effectiveness of the laboratory recall dose would decline for symptomatic forms. The Omicron variant, which is spreading at a rapid rate, undermines the effectiveness of vaccines. In any case, this is the finding from several studies carried out, particularly in South Africa and the United Kingdom. At the end of last week, the UK Health Security Agency indicated in a cautious analysis that the effectiveness of the third dose (or booster) would decline almost ten weeks after the injection. In detail, the UK study suggests that a three-dose vaccine regimen conducted solely with Pfizer-BioNTech doses provides 70% protection against symptomatic forms of coronavirus related to the Omicron variant. However, this immunity declines rapidly thereafter. Thus, this protection is no more than 45% at the end of ten weeks', 'The results of this study are to be examined with caution, as the UK Health Security Agency points out, which warns agains
# ...

# %% [markdown]
# # ***TRANSLATION MODEL -2***

# %%
#https://huggingface.co/SEBIS/legal_t5_small_trans_fr_en

import time
start_time=time.time()

from transformers import AutoTokenizer, AutoModelWithLMHead, TranslationPipeline

pipeline = TranslationPipeline(
model=AutoModelWithLMHead.from_pretrained("SEBIS/legal_t5_small_trans_fr_en"),
tokenizer=AutoTokenizer.from_pretrained(pretrained_model_name_or_path = "SEBIS/legal_t5_small_trans_fr_en", do_lower_case=False, 
                                            skip_special_tokens=True),
    device=0
)

print(pipeline([article], max_length=9000))

end_time=time.time()
print(end_time-start_time)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/modeling_auto.py:787: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   FutureWarning,
# Downloading:   0%|          | 0.00/822 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/821k [00:00<?, ?B/s]
# ...

# %% [markdown]
# # ***TRANSLATION MODEL -3***

# %%
import time
start_time=time.time()

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

mname = 'Helsinki-NLP/opus-mt-fr-en'
tokenizer = AutoTokenizer.from_pretrained(mname)
model = AutoModelForSeq2SeqLM.from_pretrained(mname)
input_ids = tokenizer.encode(article[0:2100], return_tensors="pt")
outputs = model.generate(input_ids)
decoded_1 = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded_1) 

end_time=time.time()
time_1 = end_time-start_time
print(time_1)
# Out:
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/784k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/760k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/287M [00:00<?, ?B/s]
# ...

# %% [markdown]
# It look like the 'Helsinki-NLP/opus-mt-fr-en' does a better job so I will continue using it.

# %%
import time
start_time=time.time()

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

mname = 'Helsinki-NLP/opus-mt-fr-en'
tokenizer = AutoTokenizer.from_pretrained(mname)
model = AutoModelForSeq2SeqLM.from_pretrained(mname)
input_ids = tokenizer.encode(article[2100:4200], return_tensors="pt")
outputs = model.generate(input_ids)
decoded_2 = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded_2) 

end_time=time.time()
time_2 = end_time-start_time
print(time_2)
# Out:
# Pfzer-BioNTech or Moderna. UK Health Security Agency Protection against serious forms The results of this study are to be carefully examined, as pointed out by the British health agency, which warns against possible biases related to the profile of people infected with Omicron. Moreover, the sample examined in this study is relatively limited, since it is composed of 147.587 cases of Delta variant and 68.489 cases of Omicron variant. These results are nevertheless added to a set of studies published in recent weeks and which raise the question of the efficacy of the vaccine in response to this variant. Thus, according to an analysis of real life data published on Tuesday 14 December by a South African health insurance group, protection against contamination related to the new variant would fall over time to reach 30% in the framework of a scheme carried out with two doses (only) of vaccine Pfizer-BioNTech. However, this study finds an effectiveness against serious forms (70%). It is 
# ...

# %%
time = time_1 + time_2
print(time)
# Out:
# 49.5299289226532

# %%
import time
start_time=time.time()

from transformers import MarianTokenizer, AutoModelForSeq2SeqLM

mname = 'Helsinki-NLP/opus-mt-fr-en'
tokenizer = AutoTokenizer.from_pretrained(mname)
model = AutoModelForSeq2SeqLM.from_pretrained(mname)
input_ids = tokenizer.encode(article[4200:], return_tensors="pt")
outputs = model.generate(input_ids)
decoded_3 = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded_3) 

end_time=time.time()
print(end_time-start_time)
# Out:
# I'm sorry, but I don't know.
# 4.652722597122192

# %%
decoded_output = decoded_1 + decoded_2
print(decoded_output)
# Out:
# A study by the UK Health Security Agency reports that the efficacy of the booster dose of the laboratory would decline for symptomatic forms. The Omicron variant, which spreads at a galloping rate, is undermining the efficacy of vaccines. This is in any case the finding that the effectiveness of the third dose (or booster) declines almost ten weeks after the injection. In detail, the British study suggests that a three-dose vaccination regimen performed only with doses Pfizer-BioNTech provides a 70% protection against the symptomatic forms of the coronavirus that are associated with the Omicron variant. However, this immunity declines rapidly after the injection. In detail, the British study suggests that a three-dose vaccination regimen performed only with doses Pfizer-BioNTech gives a 70% protection against the symptomatic forms of the coronavirus.Pfzer-BioNTech or Moderna. UK Health Security Agency Protection against serious forms The results of this study are to be carefully exam
# ...

# %%
decoded_output[2000:]
# Out:
# 'ses (only) of vaccine Pfizer-BioNTech. However, this study is supported by the analysis of the fact that it is not possible to examine all the diseases, the groups of the illness, the disease, and the disease, the fact to examine the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number of the number 
# ...

# %% [markdown]
# # ***SUMMARIZATION TASK***

# %%
#https://huggingface.co/t5-base
from transformers import AutoTokenizer, AutoModelWithLMHead

tokenizer = AutoTokenizer.from_pretrained("t5-base")
model = AutoModelWithLMHead.from_pretrained("t5-base")

# generate summary
input_ids = tokenizer.encode(decoded_output, return_tensors='pt')
summary_ids = model.generate(input_ids,
            min_length=20,
            max_length=5000)

summary_text = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
print(summary_text)

end_time=time.time()
print(end_time-start_time)
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/modeling_auto.py:787: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   FutureWarning,
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (718 > 512). Running this sequence through the model will result in indexing errors
# ...

# %% [markdown]
# no gramaticallly

# %%
import time
start_time=time.time()

from transformers import BartTokenizer, BartForConditionalGeneration

tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")

# generate summary
input_ids = tokenizer.encode(decoded_output, return_tensors='pt')
summary_ids = model.generate(input_ids,
            min_length=20,
            max_length=12000,
            num_beams=10,
            repetition_penalty=2.5,
            length_penalty=1.0,
            early_stopping=True,
            no_repeat_ngram_size=2,
            use_cache=True,
            do_sample = True,
            temperature = 0.8,
            top_k = 50,
            top_p = 0.95)

summary_text = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
print(summary_text)

end_time=time.time()
print(end_time-start_time)
# Out:
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:2259: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   next_indices = next_tokens // vocab_size
# ...

# %% [markdown]
# great model

# %%
#https://huggingface.co/google/pegasus-cnn_dailymail
import time
start_time=time.time()

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/pegasus-cnn_dailymail")
model = AutoModelForSeq2SeqLM.from_pretrained("google/pegasus-cnn_dailymail")

batch = tokenizer.prepare_seq2seq_batch(decoded_output, truncation=True, padding='longest', return_tensors="pt")
        
summary_ids = model.generate(**batch,num_beams=6,
                                            num_return_sequences=1,
                                            no_repeat_ngram_size = 2,
                                            length_penalty = 1,
                                            min_length = 30,
                                            max_length = 128,
                                            early_stopping = True)
        
output = [tokenizer.batch_decode(summary_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)]
print(output)

end_time=time.time()
print(end_time-start_time)
# Out:
# Downloading:   0%|          | 0.00/88.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.12G [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3426: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and the tokenizer under the `as_target_tokenizer` context manager to prepare
# your targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, ...)
# with tokenizer.as_target_tokenizer():
#     labels = tokenizer(tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# ...

# %%
#https://huggingface.co/google/pegasus-large
import time
start_time=time.time()

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/pegasus-large")
model = AutoModelForSeq2SeqLM.from_pretrained("google/pegasus-large")

batch = tokenizer.prepare_seq2seq_batch(decoded_output, truncation=True, padding='longest', return_tensors="pt")
        
summary_ids = model.generate(**batch,
                                            num_beams=6,
                                            num_return_sequences=1,
                                            no_repeat_ngram_size = 2,
                                            length_penalty = 1,
                                            min_length = 30,
                                            max_length = 12000,
                                            early_stopping = True)
        
output = [tokenizer.batch_decode(summary_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)]
print(output)

end_time=time.time()
print(end_time-start_time)
# Out:
# Downloading:   0%|          | 0.00/88.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.02k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.12G [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3426: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and the tokenizer under the `as_target_tokenizer` context manager to prepare
# your targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, ...)
# with tokenizer.as_target_tokenizer():
#     labels = tokenizer(tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# ...
